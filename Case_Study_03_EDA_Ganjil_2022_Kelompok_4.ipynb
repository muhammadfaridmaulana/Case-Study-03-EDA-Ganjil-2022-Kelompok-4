# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadfaridmaulana/Case-Study-03-EDA-Ganjil-2022-Kelompok-4/blob/main/Case_Study_03_EDA_Ganjil_2022_Kelompok_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import Data-Loading Data kota Depok, Tangerang, dan Jakarta

import pandas as pd

try: # Running Locally, yakinkan "file_" berada di folder "data"
    dfJ = pd.read_csv("data/jakarta.csv", low_memory = False, encoding='utf8')
    dfD = pd.read_csv("data/depok.csv", low_memory = False, encoding='utf8')
    dfT = pd.read_csv("data/tangerang.csv", low_memory = False, encoding='utf8')


except: # Running in Google Colab
    # !mkdir data
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/EDA-CaseStudies/main/data/jakarta.csv
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/EDA-CaseStudies/main/data/depok.csv
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/EDA-CaseStudies/main/data/tangerang.csv
    dfJ = pd.read_csv("data/jakarta.csv", low_memory = False, encoding='utf8')
    dfD = pd.read_csv("data/depok.csv", low_memory = False, encoding='utf8')
    dfT = pd.read_csv("data/tangerang.csv", low_memory = False, encoding='utf8')
    
dfJ.shape, dfD.shape, dfT.shape
# Out:
# ((1024, 26), (998, 26), (128, 26))

# %% [markdown]
# Hipotesis
# di tanggerang, Kami mengasumsikan bahwa harga rata - rata rumah diwilayah BSD  lebih tinggi dibanding di wilayah lainnya.

# %% [markdown]
# ![WhatsApp Image 2022-10-25 at 9.34.34 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Berdasarkan visualisasi di atas mengenai rata-rata harga rumah di wilayah Tangerang, terlihat bahwa pada wilayah BSD City memiliki rata-rata harga rumah cenderung lebih tinggi karena memiliki fasilitas terbaik, akses strategis, memiliki rata-rata luas tanah yang cenderung luas, dan terdapat rumah mewah dengan halaman belakang view golf.

# %%
#MENGOREKSI TIPE VARIABEL KOTA TANGERANG
dfT['sertifikat'] = dfT['sertifikat'].astype('category')
dfT['hadap'] = dfT['hadap'].astype('category')
dfT['lokasi'] = dfT['lokasi'].astype('category')
dfT['created_at'] = dfT['created_at'].astype('category')
dfT['URL'] = dfT['URL'].astype('category')
dfT['deskripsi'] = dfT['deskripsi'].astype('category')
dfT.dtypes

# %%
t = dfT.dropna(axis = 0, how = "all")
Tangerang = t.dropna(axis = 1, how = "all")
Tangerang
#Data Tangerang yang sudah bersih

# %%
#REMOVING DATA VARIABLE TANGERANG
dfT.columns
try: 
  dfT.drop("sertifikat", axis=1, inplace=True)
  dfT.drop("URL", axis=1, inplace=True)
  dfT.head()
except:
  pass

# %% [markdown]
# di tanggerang, Kami mengasumsikan bahwa harga rata - rata rumah diwilayah BSD  lebih tinggi dibanding di wilayah lainnya.

# %% [markdown]
# ![WhatsApp Image 2022-10-25 at 9.06.52 AM (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Berdasarkan visualisasi di atas mengenai rata-rata harga rumah di wilayah Depok, terlihat bahwa rumah-rumah pada wilayah Limo memiliki rata-rata harga rumah cenderung lebih tinggi. Tetapi pada wilayah Limo hanya terdapat 2 rumah yang terdaftar sehingga hasil rata-rata harga rumah diatas tidak valid. Sehingga, ada kemungkinan bahwa rumah-rumah pada wilayah cinere memiliki harga yang cenderung lebih tinggi dibanding wilayah lain.

# %%
#REMOVING DATA VARIABLE DEPOK
dfD.columns
# Out:
# Index(['created_at', 'LT', 'LB', 'KT', 'KM', 'garasi', 'carport', 'lokasi',
#        'sertifikat', 'listrik', 'hadap', 'harga', 'URL', 'deskripsi',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
#MENGOREKSI TIPE VARIABEL KOTA DEPOK
dfD['sertifikat'] = dfD['sertifikat'].astype('category')
dfD['hadap'] = dfD['hadap'].astype('category')
dfD['lokasi'] = dfD['lokasi'].astype('category')
dfD['created_at'] = dfD['created_at'].astype('category')
dfD['URL'] = dfD['URL'].astype('category')
dfD['deskripsi'] = dfD['deskripsi'].astype('category')
dfD.dtypes

# %%
#REMOVING DATA VARIABLE DEPOK
dfD.columns

# %% [markdown]
# ### telah mengasumsikan harga rata - rata di Jakarta Selatan lebih tinggi dibanding wilayah lainnya di jakarta karena banyak faktor yang menyebabkan harga yang menjadi tinggi. Contohnya seperti wilayah yang dekat dengan pusat Industri.

# %% [markdown]
# ![b1986769-0660-4321-a606-d833fed9f395.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Berdasarkan visualisasi di atas mengenai rata-rata harga perwilayah di Jakarta. Sepertinya rumah-rumah yang berada pada wilayah Jakarta Selatan memiliki harga rumah cenderung lebih tinggi dibandingan Jakarta Pusat, Jakarta Barat, Jakarta Utara, dan Jakarta Timur. Rumah-rumah pada wilayah Jakarta Selatan memiliki harga yang cenderung lebih tinggi karena berada di lokasi yang strategis dan bebas banjir.

# %% [markdown]
# ![WhatsApp Image 2022-10-25 at 9.46.11 AM.jpeg](data:image/jpeg;base64,...)

# %%
a = dfJ.dropna(axis = 0, how = "all")
Jakarta = a.dropna(axis = 1, how = "all")
Jakarta
#

# %%
#MENGOREKSI TIPE VARIABEL KOTA JAKARTA
dfJ['sertifikat'] = dfJ['sertifikat'].astype('category')
dfJ['hadap'] = dfJ['hadap'].astype('category')
dfJ['lokasi'] = dfJ['lokasi'].astype('category')
dfJ['created_at'] = dfJ['created_at'].astype('category')
dfJ['URL'] = dfJ['URL'].astype('category')
dfJ['deskripsi'] = dfJ['deskripsi'].astype('category')
dfJ.dtypes

# %%
a = dfJ.dropna(axis = 0, how = "all")
Jakarta = a.dropna(axis = 1, how = "all")
Jakarta
#Data Jakarta yang sudah bersih

# %%
#REMOVING DATA VARIABLE JAKARTA
dfJ.columns

dfJ.drop("sertifikat", axis=1, inplace=True)
dfJ.drop("URL", axis=1, inplace=True)
dfJ.head()
# Out:
#    created_at     LT     LB   KT   KM  garasi  carport         lokasi  \
# 0  06-12-2021  202.0  198.0  8.0  3.0     NaN      NaN  Jakarta Pusat
# 1  02-12-2021   30.0   55.0  2.0  1.0     NaN      1.0  Jakarta Pusat
# 2  06-12-2021   19.0   35.0  2.0  1.0     NaN      NaN  Jakarta Pusat
# 3  06-12-2021   33.0   42.0  2.0  2.0     NaN      1.0  Jakarta Pusat
# 4  06-12-2021   30.0   55.0  2.0  2.0     NaN      1.0  Jakarta Pusat
#
#    listrik hadap  ...  Unnamed: 16 Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# 0   2200.0   NaN  ...          NaN         NaN          NaN          NaN
# 1   2200.0   NaN  ...          NaN         NaN          NaN          NaN
# 2   2200.0   NaN  ...          NaN         NaN          NaN          NaN
# 3   2200.0   NaN  ...          NaN         NaN          NaN          NaN
# 4   2200.0   NaN  ...          NaN         NaN          NaN          NaN
#
#    Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# ...
